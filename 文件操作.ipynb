# %%
with open('yanyou.txt') as yanyou_file:
    content = yanyou_file.read()
    print(content.strip())
    print(len(content.strip()))
# Out:
# 本书简介：
#
# 她是刚刚学会做爱，
# 所以稍微放肆了一点。
# 勾引了校花的男朋友，勾搭上同班的不良少年还睡了她的家教……
# 爸妈知道之后的偏激反应直接导致她被送去了住宿学校。
# 原本还以为会像个尼姑一样禁欲一整个学期。
# 但谁知道这个表面上宁静又保守的学校里充满了暴力和色情……
# 她不同意XX就被OO，
# 同意OO了又被另一个人XX。
# 这是一个从欲求不满的无知少女蜕变成为令学院两大帅哥大打出手的祸水的故事。
# 197

# %%
with open('yanyou.txt') as yanyou_file:
    for line in yanyou_file.read():
        print(line.strip())
# Out:
# 本
# 书
# 简
# 介
# ：
#
#
# 她
# 是
# 刚
# 刚
# 学
# 会
# 做
# 爱
# ，
#
# 所
# 以
# 稍
# 微
# 放
# 肆
# 了
# 一
# 点
# 。
#
# 勾
# 引
# 了
# 校
# 花
# 的
# 男
# 朋
# 友
# ，
# 勾
# 搭
# 上
# 同
# 班
# 的
# 不
# 良
# 少
# 年
# 还
# 睡
# 了
# 她
# 的
# 家
# 教
# …
# …
#
# 爸
# 妈
# 知
# 道
# 之
# 后
# 的
# 偏
# 激
# 反
# 应
# 直
# 接
# 导
# 致
# 她
# 被
# 送
# 去
# 了
# 住
# 宿
# 学
# 校
# 。
#
# 原
# 本
# 还
# 以
# 为
# 会
# 像
# 个
# 尼
# 姑
# 一
# 样
# 禁
# 欲
# 一
# 整
# 个
# 学
# 期
# 。
#
# 但
# 谁
# 知
# 道
# 这
# 个
# 表
# 面
# 上
# 宁
# 静
# 又
# 保
# 守
# 的
# 学
# 校
# 里
# 充
# 满
# 了
# 暴
# 力
# 和
# 色
# 情
# …
# …
#
# 她
# 不
# 同
# 意
# X
# X
# 就
# 被
# O
# O
# ，
#
# 同
# 意
# O
# O
# 了
# 又
# 被
# 另
# 一
# 个
# 人
# X
# X
# 。
#
# 这
# 是
# 一
# 个
# 从
# 欲
# 求
# 不
# 满
# 的
# 无
# 知
# 少
# 女
# 蜕
# 变
# 成
# 为
# 令
# 学
# 院
# 两
# 大
# 帅
# 哥
# 大
# 打
# 出
# 手
# 的
# 祸
# 水
# 的
# 故
# 事
# 。

# %%
file_name = "yanyou.txt"
with open(file_name) as file_object:
    lines = file_object.readlines()
    file = ""
for line in lines[:13]:
   file += line.strip()
print(file[:100:2])
print(file[1:100:2])
print(len(file))
# Out:
# 本简：是刚会爱所稍放了点勾了花男友勾上班不少还了的教…妈道后偏反直导她送了宿校原还为像尼一禁一个期但
# 书介她刚学做，以微肆一。引校的朋，搭同的良年睡她家…爸知之的激应接致被去住学。本以会个姑样欲整学。谁
# 187

# %%
with open('yanyou.txt') as yy:
    lines = yy.readlines()
file = ""
for line in lines:
    file += line.strip()
    
name = input("请输入名字: ")
if name in file:
    print(True)
else:
    print(False)

# %%
filename = "firstfile.txt"
with open(filename,"w") as fn:
    fn.write("1this is my first file.\n")
    fn.write('2hello,world!\n')

# %%
filename = "firstfile.txt"
with open(filename,"a") as fin:
    fin.write("3this is my first file.\n")
    fin.write('4hello,world!\n')

# %%
filename = 'namelist.txt'
with open(filename, "a") as nl:
    while True:
        name = input("请输入你的名字(q退出):  ")
        if name == "q":
            break
        else:
            nl.write(name + " \n")

# %%
filename = 'namelist.txt'
with open(filename) as nl:
    line = nl.readlines()
    file = ""
for n in line:
    file += n
name = input('name: ')
if name in file:
    print("good")
else:
    print("OK")

# %%
try:           #试着运行以下代码块,失败则运行except代码块.并继续运行以后的代码.
    prie(0)
except:
    print("xxxx")
a = 2 + 3
print(a)

# %%
import json  #json模块用来存储数据
number = [1, 22, 45, 38, 33, 44]
filmname = 'number.json'
with open(filmname, 'w') as f_obj:
    json.dump(number, f_obj)

# %%
import json
filename = 'number.json'
with open(filmname, 'r') as f_obj:
    numbers = json.load(f_obj)
print(numbers)

# %%
import json
while True:
    username = input('Please input your name(q to quit): ')
    if username == "q":
        break
    else:
        filename = "usernames.json"
        with open(filename, 'a') as f_obj:
            username_full = '/nUsername:   ' + username
            json.dump(username_full, f_obj)
            print('We will remamber your name:  ', username)
